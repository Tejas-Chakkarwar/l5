# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv('/content/Google_Stock_Price_Train.csv')
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   object
#  5   Volume  1258 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 59.1+ KB

# %%
test_df = pd.read_csv('/content/Google_Stock_Price_Test.csv')
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Open    20 non-null     float64
#  2   High    20 non-null     float64
#  3   Low     20 non-null     float64
#  4   Close   20 non-null     float64
#  5   Volume  20 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 1.1+ KB

# %%
train = train_df.loc[:,['Open']].values
train.shape
# Out:
# (1258, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
train_scaled = scaler.fit_transform(train)

# %%
plt.plot(train_scaled)
plt.ylabel("Standardized Values")
plt.xlabel("Time->")
plt.show()

# %%
x_train = []
y_train = []
time = 60
for i in range(60,train_scaled.shape[0]):
    x_train.append(train_scaled[i-60:i,0])
    y_train.append(train_scaled[i,0])
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train.shape,y_train.shape
# Out:
# ((1198, 60), (1198,))

# %%
x_train = np.reshape(x_train,newshape=(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1198, 60, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN,Dropout

# %%
model = Sequential()

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50,activation = "tanh", return_sequences = True))
model.add(Dropout(0.2))

model.add(SimpleRNN(units=50))
model.add(Dropout(0.2))

model.add(Dense(units=1))

model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 60, 50)            2600
#
#  dropout (Dropout)           (None, 60, 50)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 60, 50)            5050
#
#  dropout_1 (Dropout)         (None, 60, 50)            0
#
#  simple_rnn_2 (SimpleRNN)    (None, 60, 50)            5050
#
#  dropout_2 (Dropout)         (None, 60, 50)            0
#
#  simple_rnn_3 (SimpleRNN)    (None, 50)                5050
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 17,801
# Trainable params: 17,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=100,batch_size=30,validation_split=0.05)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 8s 76ms/step - loss: 0.3121 - val_loss: 0.0160
# Epoch 2/100
# 38/38 [==============================] - 2s 56ms/step - loss: 0.2050 - val_loss: 0.0109
# Epoch 3/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.1474 - val_loss: 0.0186
# Epoch 4/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.1201 - val_loss: 0.0249
# Epoch 5/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0797 - val_loss: 0.0054
# Epoch 6/100
# 38/38 [==============================] - 3s 69ms/step - loss: 0.0671 - val_loss: 0.0147
# Epoch 7/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0624 - val_loss: 0.0163
# Epoch 8/100
# 38/38 [==============================] - 2s 56ms/step - loss: 0.0470 - val_loss: 0.0124
# Epoch 9/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0412 - val_loss: 0.0141
# Epoch 10/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0349 - val_loss: 0.0036
# Epoch 11/100
# 38/38 [==============================] - 3s 68ms/step - loss: 0.0316 - val_loss: 0.0155
# Epoch 12/100
# 38/38 [==============================] - 3s 70ms/step - loss: 0.0322 - val_loss: 0.0031
# Epoch 13/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0260 - val_loss: 0.0014
# Epoch 14/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0215 - val_loss: 0.0073
# Epoch 15/100
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0194 - val_loss: 0.0138
# Epoch 16/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0188 - val_loss: 0.0103
# Epoch 17/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0174 - val_loss: 0.0013
# Epoch 18/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0157 - val_loss: 0.0038
# Epoch 19/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0146 - val_loss: 0.0054
# Epoch 20/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0138 - val_loss: 0.0031
# Epoch 21/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0128 - val_loss: 0.0096
# Epoch 22/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0118 - val_loss: 0.0036
# Epoch 23/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0101 - val_loss: 0.0068
# Epoch 24/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0105 - val_loss: 0.0048
# Epoch 25/100
# 38/38 [==============================] - 3s 74ms/step - loss: 0.0105 - val_loss: 0.0017
# Epoch 26/100
# 38/38 [==============================] - 3s 73ms/step - loss: 0.0100 - val_loss: 7.5753e-04
# Epoch 27/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0078 - val_loss: 0.0030
# Epoch 28/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0077 - val_loss: 0.0075
# Epoch 29/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0085 - val_loss: 6.2236e-04
# Epoch 30/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0075 - val_loss: 0.0011
# Epoch 31/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0068 - val_loss: 0.0051
# Epoch 32/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 33/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0057 - val_loss: 0.0017
# Epoch 34/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0056 - val_loss: 0.0017
# Epoch 35/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0056 - val_loss: 0.0016
# Epoch 36/100
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0059 - val_loss: 5.5237e-04
# Epoch 37/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0057 - val_loss: 0.0034
# Epoch 38/100
# 38/38 [==============================] - 2s 59ms/step - loss: 0.0051 - val_loss: 0.0038
# Epoch 39/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0049 - val_loss: 0.0037
# Epoch 40/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0049 - val_loss: 0.0031
# Epoch 41/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0044 - val_loss: 8.6167e-04
# Epoch 42/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0043 - val_loss: 6.4900e-04
# Epoch 43/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0040 - val_loss: 0.0024
# Epoch 44/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 45/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0042 - val_loss: 0.0020
# Epoch 46/100
# 38/38 [==============================] - 4s 114ms/step - loss: 0.0040 - val_loss: 5.3267e-04
# Epoch 47/100
# 38/38 [==============================] - 3s 62ms/step - loss: 0.0041 - val_loss: 0.0011
# Epoch 48/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0037 - val_loss: 0.0016
# Epoch 49/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 50/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0037 - val_loss: 0.0020
# Epoch 51/100
# 38/38 [==============================] - 3s 76ms/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 52/100
# 38/38 [==============================] - 3s 71ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 53/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0039 - val_loss: 0.0012
# Epoch 54/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 55/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0031 - val_loss: 5.9520e-04
# Epoch 56/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0031 - val_loss: 5.3326e-04
# Epoch 57/100
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0030 - val_loss: 5.4199e-04
# Epoch 58/100
# 38/38 [==============================] - 2s 59ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 59/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 60/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 61/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0029 - val_loss: 5.6800e-04
# Epoch 62/100
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0027 - val_loss: 5.7844e-04
# Epoch 63/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0027 - val_loss: 8.2023e-04
# Epoch 64/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0027 - val_loss: 7.0322e-04
# Epoch 65/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0027 - val_loss: 5.5730e-04
# Epoch 66/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0026 - val_loss: 6.2038e-04
# Epoch 67/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0025 - val_loss: 7.1644e-04
# Epoch 68/100
# 38/38 [==============================] - 3s 67ms/step - loss: 0.0023 - val_loss: 6.1233e-04
# Epoch 69/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0023 - val_loss: 6.7467e-04
# Epoch 70/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0022 - val_loss: 6.5987e-04
# Epoch 71/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0026 - val_loss: 5.1557e-04
# Epoch 72/100
# 38/38 [==============================] - 2s 65ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 73/100
# 38/38 [==============================] - 3s 82ms/step - loss: 0.0025 - val_loss: 6.7977e-04
# Epoch 74/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0023 - val_loss: 7.0767e-04
# Epoch 75/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0024 - val_loss: 6.7795e-04
# Epoch 76/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0023 - val_loss: 9.2195e-04
# Epoch 77/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0019 - val_loss: 5.1401e-04
# Epoch 78/100
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0021 - val_loss: 7.6063e-04
# Epoch 79/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 80/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0022 - val_loss: 9.4546e-04
# Epoch 81/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0020 - val_loss: 9.4751e-04
# Epoch 82/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0022 - val_loss: 5.1625e-04
# Epoch 83/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0021 - val_loss: 8.8820e-04
# Epoch 84/100
# 38/38 [==============================] - 2s 59ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 85/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0018 - val_loss: 5.0308e-04
# Epoch 86/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 87/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0019 - val_loss: 5.7797e-04
# Epoch 88/100
# 38/38 [==============================] - 3s 76ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 89/100
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0018 - val_loss: 5.6084e-04
# Epoch 90/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0018 - val_loss: 5.4876e-04
# Epoch 91/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0017 - val_loss: 5.4578e-04
# Epoch 92/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0016 - val_loss: 5.3217e-04
# Epoch 93/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0020 - val_loss: 5.5599e-04
# Epoch 94/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0018 - val_loss: 8.3199e-04
# Epoch 95/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0018 - val_loss: 6.6614e-04
# Epoch 96/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 97/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 98/100
# 38/38 [==============================] - 2s 57ms/step - loss: 0.0017 - val_loss: 7.8763e-04
# Epoch 99/100
# 38/38 [==============================] - 3s 93ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 100/100
# 38/38 [==============================] - 2s 58ms/step - loss: 0.0015 - val_loss: 0.0010

# %%
data = pd.concat((train_df['Open'],test_df['Open']),axis=0)

# %%
test_input = data.iloc[len(data) - len(test_df) - time : ].values
test_input.shape
# Out:
# (80,)

# %%
test_input = test_input.reshape(-1,1)
test_input.shape
# Out:
# (80, 1)

# %%
test_scaled = scaler.transform(test_input)

# %%
x_test = []
for i in range(time,test_scaled.shape[0]):
    x_test.append(test_scaled[i - time: i,0 ])
x_test = np.array(x_test)
x_test.shape
# Out:
# (20, 60)

# %%
x_test = np.reshape(x_test,newshape=(x_test.shape[0],x_test.shape[1],1))
x_test.shape
# Out:
# (20, 60, 1)

# %%
y_test = test_df.loc[:,"Open"].values

# %%
y_pred = model.predict(x_test)
# Out:
# 1/1 [==============================] - 1s 779ms/step

# %%
y_pred = scaler.inverse_transform(y_pred)

# %%
output = model.evaluate(x=x_test,y=y_test)
# Out:
# 1/1 [==============================] - 1s 821ms/step - loss: 650811.0000

# %%
plt.plot(y_test, color = 'red', label = 'Real price')
plt.plot(y_pred, color = 'blue', label = 'Predicted price')

plt.title('Google Stock price prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
